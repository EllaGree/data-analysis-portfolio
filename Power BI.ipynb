# %%
import pandas as pd

data = {
    'Month':      ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Revenue':    [15000, 18000, 14000, 22000, 19000, 25000],
    'Customers':  [120, 145, 110, 180, 160, 200],
    'Complaints': [15, 12, 18, 8, 10, 6],
    'Department': ['Sales', 'Tech', 'Sales', 'HR', 'Tech', 'Sales'],
    'Salary':     [3200, 5800, 3900, 4500, 5100, 3800]
}

df = pd.DataFrame(data)
df.to_csv('C:/Users/danie/business_data.csv', index=False)
print("CSV saved!")
# Out:
# CSV saved!
